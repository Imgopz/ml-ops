# %% [markdown]
# #### Ml Workflow

# %%
from IPython.display import Image
Image("mlflow.png")

# %% [markdown]
# How MLFLOW will be useful for Data Scientists?
#
# 1. Experiment tracking and hypothesis testing,
# 2. Code structuring,
# 3. Model packaging & Dependency management,
# 4. Evaluating hyperparameter tuning (Track Hyperparameter Tuning along with visualization),
# 5. Compare the results for models retraining over time.

# %% [markdown]
# How MLFLOW will be useful for ML Engineers?
#
# 1. Manage the lifecycle of trained models, both pre and post deployment,
# 2. Deploy models securely to the production environment,
# 3. Manage deployment depedencies.

# %% [markdown]
# How MLFLOW will be useful for Prompt Engineering?
#
# 1. Evaluate and experiment with large language models,
# 2. Create custom prompts and expermint,
# 3. Deciding on the best base model suitable.

# %% [markdown]
# Use cases,
#
# 1. Experiment Tracking -> Track parameters and metrics (UI),
# 2. Model selection and deployment,
# 3. Model performance and monitoring,
# 4. Collaborative project.
